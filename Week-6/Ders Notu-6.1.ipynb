# %%
#kütüphanelerin import edilmesi 
import numpy as np
import pandas as pd

# %%
import os
os.listdir()
# Out:
# ['Week-2',
#  'Week-5',
#  '.DS_Store',
#  'Untitled.ipynb',
#  'Görseller',
#  'Week-6',
#  'Week-1',
#  'Extra_Study',
#  '.ipynb_checkpoints',
#  '.git']

# %%
df = pd.read_csv("Week-6/jobs_in_data.csv")
df
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
#ilk 5 satırına göz gezdirelim
df.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
#son 5 satırına göz gezdirelim
df.tail()
# Out:
#       work_year                 job_title                  job_category  \
# 9350       2021           Data Specialist  Data Management and Strategy
# 9351       2020            Data Scientist     Data Science and Research
# 9352       2021  Principal Data Scientist     Data Science and Research
# 9353       2020            Data Scientist     Data Science and Research
# 9354       2020     Business Data Analyst                 Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# 9350             USD  165000         165000      United States
# 9351             USD  412000         412000      United States
# 9352             USD  151000         151000      United States
# 9353             USD  105000         105000      United States
# 9354             USD  100000         100000      United States
#
#      experience_level employment_type work_setting company_location  \
# 9350           Senior       Full-time       Remote    United States
# ...

# %% [markdown]
# **.info() metodu**, genellikle pandas kütüphanesi ile kullanılan ve bir DataFrame hakkında özet bilgi sağlayan bir fonksiyondur. Bu özet bilgi, veri setinin genel yapısını anlamak için oldukça faydalıdır.
#
#     .info() Metodunun Sağladığı Bilgiler:
#
# - Veri Tipleri: Hangi sütunun hangi veri tipine (örneğin, int, float, object (string), datetime) sahip olduğunu gösterir.
# - Sütun İsimleri: Veri setindeki tüm sütunların isimlerini listeler.
# - Null (Eksik) Değerler: Her sütundaki eksik (null) değerlerin sayısını gösterir.
# - Sütun Sayısı ve Satır Sayısı: DataFrame'deki toplam satır ve sütun sayısını belirtir.
# - Bellek Kullanımı: DataFrame'in bellekte ne kadar yer kapladığını gösterir.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB

# %% [markdown]
# .describe() metodu, genellikle pandas kütüphanesi ile kullanılan ve bir DataFrame'in sayısal sütunları hakkında özet istatistiksel bilgi sağlayan bir fonksiyondur. Bu metod, veri setinin istatistiksel özelliklerini hızlı bir şekilde anlamak için oldukça kullanışlıdır.
#
#
#     .describe() Metodunun Sağladığı Bilgiler:
# - count: Her sütundaki toplam veri noktası sayısını gösterir.
# - mean: Her sütunun ortalama değerini hesaplar.
# - std: Her sütunun standart sapmasını gösterir.
# - min: Her sütundaki en küçük değeri belirtir.
# - 25% (1. çeyrek): Her sütundaki değerlerin %25'inin altında kaldığı değeri gösterir.
# - 50% (Medyan): Her sütundaki değerlerin %50'sinin altında kaldığı değeri belirtir (medyan).
# - 75% (3. çeyrek): Her sütundaki değerlerin %75'inin altında kaldığı değeri gösterir.
# - max: Her sütundaki en büyük değeri belirtir.

# %%
df.describe()
# Out:
#          work_year         salary  salary_in_usd
# count  9355.000000    9355.000000    9355.000000
# mean   2022.760449  149927.981293  150299.495564
# std       0.519470   63608.835387   63177.372024
# min    2020.000000   14000.000000   15000.000000
# 25%    2023.000000  105200.000000  105700.000000
# 50%    2023.000000  143860.000000  143000.000000
# 75%    2023.000000  187000.000000  186723.000000
# max    2023.000000  450000.000000  450000.000000

# %% [markdown]
# - isnull(): Bu metod, bir DataFrame veya Serideki her bir değerin eksik olup olmadığını kontrol eder ve aynı boyutta bir DataFrame veya Seri döndürür.
#
# - any(): Bu metod, eksik değerler için True olan sütunların olup olmadığını kontrol eder. Her sütun için herhangi bir True değeri varsa, o sütun için True döner.

# %%
df.isnull().any()
# Out:
# work_year             False
# job_title             False
# job_category          False
# salary_currency       False
# salary                False
# salary_in_usd         False
# employee_residence    False
# experience_level      False
# employment_type       False
# work_setting          False
# company_location      False
# company_size          False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# work_year             0
# job_title             0
# job_category          0
# salary_currency       0
# salary                0
# salary_in_usd         0
# employee_residence    0
# experience_level      0
# employment_type       0
# work_setting          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
#     .unique() Metodu:
#
# - Amacı: Bir Seri veya DataFrame'in belirli bir sütunundaki benzersiz (tekrarsız) değerleri döndürür.
#
# - Kullanım Alanı: Veri setinde hangi değerlerin bulunduğunu ve tekrar eden değerleri görmek için kullanılır.
#
# - Dönüş Değeri: Benzersiz değerleri içeren bir NumPy array döndürür.

# %%
df.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
df["work_year"].unique()
# Out:
# array([2023, 2022, 2020, 2021])

# %%
df["salary_currency"].unique()
# Out:
# array(['EUR', 'USD', 'GBP', 'CAD', 'AUD', 'PLN', 'BRL', 'TRY', 'CHF',
#        'SGD', 'DKK'], dtype=object)

# %%
df["company_size"].unique()
# Out:
# array(['L', 'M', 'S'], dtype=object)

# %% [markdown]
#  .value_counts() Metodu:
#
# - Amacı: Bir Seri içindeki benzersiz değerlerin frekansını (kaç kez tekrar ettiklerini) sayar.
# - Kullanım Alanı: Kategorik verilerin dağılımını ve her bir değerin ne sıklıkta tekrarlandığını görmek için kullanılır.
# - Dönüş Değeri: Benzersiz değerleri ve bunların frekanslarını içeren bir pandas Seri döndürür, sıklıkla azalan düzende sıralanır.

# %%
df["work_year"].value_counts()
# Out:
# work_year
# 2023    7453
# 2022    1634
# 2021     197
# 2020      71
# Name: count, dtype: int64

# %%
df["company_size"].value_counts()
# Out:
# company_size
# M    8448
# L     748
# S     159
# Name: count, dtype: int64

# %% [markdown]
#     .groupby() Metodu:
# - Amacı: Bir DataFrame'i belirtilen bir veya daha fazla sütuna göre gruplar ve bu gruplar üzerinde toplu işlemler (aggregate functions) gerçekleştirilmesini sağlar.
# - Kullanım Alanı: Veriyi gruplar halinde özetlemek, analiz etmek ve toplu işlemler yapmak için kullanılır.
# - Syntax: df.groupby('sütun_adı')

# %%
df.groupby("work_year")[["salary_in_usd"]].mean().reset_index()
# Out:
#    work_year  salary_in_usd
# 0       2020  105878.859155
# 1       2021  106483.644670
# 2       2022  135467.501836
# 3       2023  155132.591708

# %%
df.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
df.groupby("job_category")[["salary_in_usd"]].mean().reset_index()
# Out:
#                      job_category  salary_in_usd
# 0            BI and Visualization  135092.102236
# 1              Cloud and Database  155000.000000
# 2                   Data Analysis  108505.721345
# 3  Data Architecture and Modeling  156002.359073
# 4                Data Engineering  146197.656195
# 5    Data Management and Strategy  103139.934426
# 6     Data Quality and Operations  100879.472727
# 7       Data Science and Research  163758.575979
# 8       Leadership and Management  145476.019881
# 9         Machine Learning and AI  178925.847339

# %% [markdown]
#     sort_values(): DataFrame içindeki değerleri sıralamak için kullanılan metod.
#
# - by="salary_in_usd": Sıralama işleminin salary_in_usd sütununa göre yapılacağını belirtir.
#
# - ascending=False: Sıralamanın azalan düzende yapılacağını belirtir. Yani, en yüksek maaşlar üstte olacak şekilde sıralama yapılır.

# %%
df.groupby("job_category")[["salary_in_usd"]].mean().sort_values(by="salary_in_usd",ascending=False).reset_index()
# Out:
#                      job_category  salary_in_usd
# 0         Machine Learning and AI  178925.847339
# 1       Data Science and Research  163758.575979
# 2  Data Architecture and Modeling  156002.359073
# 3              Cloud and Database  155000.000000
# 4                Data Engineering  146197.656195
# 5       Leadership and Management  145476.019881
# 6            BI and Visualization  135092.102236
# 7                   Data Analysis  108505.721345
# 8    Data Management and Strategy  103139.934426
# 9     Data Quality and Operations  100879.472727

# %% [markdown]
# **matplotlib.pyplot**
#
# matplotlib.pyplot, matplotlib kütüphanesinin bir parçası olan ve grafiklerin oluşturulmasını sağlayan bir modüldür. Grafiklerin çiziminde kullanılan temel fonksiyonları sağlar ve genellikle veri görselleştirme işlemlerinde kullanılır.
#
# Temel Kullanım:
#
# Ana Fonksiyonlar:
# - plt.plot(): Çizgi grafiği oluşturur.
# - plt.scatter(): Dağılım grafiği oluşturur.
# - plt.bar(): Çubuk grafiği oluşturur.
# - plt.hist(): Histogram oluşturur.
# - plt.title(): Grafiğe başlık ekler.
# - plt.xlabel(), plt.ylabel(): X ve Y eksenlerine etiket ekler.
# - plt.show(): Grafiği ekranda gösterir.
# - plt.figure(): Yeni bir figür (grafik penceresi) oluşturur. Bu, grafiğin çizileceği alanı tanımlar.
# - figsize=(18, 5): Figürün genişlik ve yükseklik boyutlarını inç cinsinden ayarlar. Örnekte, figürün genişliği 18 inç ve yüksekliği 5 inç olarak ayarlanmıştır.
# - plt.xticks(): X eksenindeki etiketlerin özelliklerini ayarlamak için kullanılır.
# - rotation=90: X eksenindeki etiketleri 90 derece döndürür. Bu, etiketlerin dikey olarak hizalanmasını sağlar ve uzun etiketlerin okunabilirliğini artırır.
#
#     **Seaborn**
#
# Seaborn, istatistiksel veri görselleştirmesi için tasarlanmış bir Python kütüphanesidir ve matplotlib'in üzerine inşa edilmiştir. Veri analizi ve görselleştirmeyi daha kolay ve estetik hale getirmeyi amaçlar.
#
# Temel Kullanım:
#
# Ana Fonksiyonlar:
# - sns.scatterplot(): Dağılım grafiği oluşturur.
# - sns.lineplot(): Çizgi grafiği oluşturur.
# - sns.barplot(): Çubuk grafiği oluşturur.
# - sns.histplot(): Histogram oluşturur.
# - sns.boxplot(): Kutu grafiği oluşturur.
# - sns.heatmap(): Isı haritası oluşturur.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
#    **Çubuk Grafikler için Bilinmesi Gerekenler**
# - Kategorik Veri Temsili: Çubuk grafikler, kategorik verileri (örneğin, farklı şehirler, ürün türleri) net bir şekilde görselleştirmek için kullanılır. Her çubuk, belirli bir kategoriyi temsil eder.
# - Değer Karşılaştırması: Çubukların uzunluğu veya yüksekliği, kategoriler arasındaki değerleri doğrudan karşılaştırmak için görsel bir yol sağlar. Uzun çubuklar yüksek değerleri, kısa çubuklar düşük değerleri temsil eder.
# - Netlik ve Anlaşılabilirlik: Çubuk grafikler, verileri açık ve anlaşılır bir şekilde sunar. Kategoriler arasındaki farklar kolayca gözlemlenebilir, bu da verilerin hızlıca analiz edilmesini sağlar.
# - Renk ve Etiketler: Çubuk grafiklerde çubuklar farklı renklerde olabilir ve her çubuğun üzerinde veya altında etiketler bulunur. Bu, verilerin daha iyi anlaşılmasını ve grafik üzerinde kolayca tanımlanmasını sağlar.

# %% [markdown]
# - plt.figure(): Yeni bir grafik alanı (canvas) oluşturur.
# - figsize=(x, y): Grafik alanının genişlik ve yüksekliğini (inch cinsinden) belirler.
# - plt.bar(): Dikey çubuklardan oluşan bar (çubuk) grafiği çizer.
# - x=: X eksenine hangi sütunun geleceğini belirtir (kategoriler, tarih vb.).
# - height=: Her çubuğun yüksekliğini belirleyen sütunu seçer (sayısal değerler).
# - data=: Grafiğe temel olacak veri kaynağı DataFrame’i belirtir.
# - plt.xticks(rotation=…): X eksenindeki etiketlerin dönme açısını ayarlar (örneğin 90 = dikey yazı).

# %%
#grafiğin veri kaynağı burada
group_category_salary = df.groupby("job_category")[["salary_in_usd"]].mean().sort_values(by="salary_in_usd",ascending=False).reset_index()
group_category_salary
# Out:
#                      job_category  salary_in_usd
# 0         Machine Learning and AI  178925.847339
# 1       Data Science and Research  163758.575979
# 2  Data Architecture and Modeling  156002.359073
# 3              Cloud and Database  155000.000000
# 4                Data Engineering  146197.656195
# 5       Leadership and Management  145476.019881
# 6            BI and Visualization  135092.102236
# 7                   Data Analysis  108505.721345
# 8    Data Management and Strategy  103139.934426
# 9     Data Quality and Operations  100879.472727

# %%
#matplotlib ile çubuk grafiği oluşturalım

plt.figure(figsize=(15,5)) #Grafiğini boyutunu belirler
plt.bar(x = "job_category", height = "salary_in_usd", data = group_category_salary)
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(15,5)) #Grafiğini boyutunu belirler
sns.barplot(x = "job_category", y = "salary_in_usd", data = group_category_salary)
plt.xticks(rotation=90);
sns.barplot(x="job_category", y="salary_in_usd", data=group_category_salary, hue="job_category", palette="coolwarm", dodge=False)
# Out:
# <Axes: xlabel='job_category', ylabel='salary_in_usd'>

# %% [markdown]
# **💎 Diğer hazır paletler**
#
# - "deep" → (varsayılan koyu renkler)
# - "muted" → daha yumuşak tonlar
# - "bright" → parlak ve canlı
# - "pastel" → açık, tatlı renkler
# - "dark" → koyu renkler
# - "colorblind" → renk körü dostu
#
# **💎 Özel paletler**
#
# - palette = sns.color_palette("Blues")
# - palette = sns.color_palette("coolwarm")
# - palette = sns.color_palette("magma")
# - palette = sns.color_palette("viridis")
# - palette = sns.color_palette("cubehelix")
# - palette = sns.color_palette("flare")
# - palette = sns.color_palette("crest")
#
#
# -- İstersen "hls", "husl", "ch:s=-.2,r=.6" gibi özel renk uzaylarından da otomatik palet üretebilirsin.
#
# Kendi renklerini HEX kodlarıyla verebilirsin:
# - palette = ["#FF9999", "#66B3FF", "#99FF99", "#FFCC99"]
#
#
# palette = ["#FF9999", "#66B3FF", "#99FF99"]
# sns.barplot(x="job_category", y="salary_in_usd", data=group_category_salary, palette=palette)

# %% [markdown]
# **Boxplot (Kutu Grafiği) Nedir?**
# - Boxplot, bir veri setinin dağılımını özetleyen istatistiksel bir grafiktir.
#
# **Medyan ve Çeyrekler:**
# - Kutunun ortasındaki çizgi medyanı, kenarları 1. (Q1) ve 3. (Q3) çeyrekleri gösterir.
#
# **IQR (Çeyrekler Arası Mesafe):**
# - Kutunun boyu Q1 ile Q3 arasındaki farktır; verinin ortadaki %50’sini temsil eder.
#
# **Aykırı Değerler:**
# - IQR’ın 1.5 katı dışındaki değerler aykırı kabul edilir ve noktalarla gösterilir.
#
# **Whiskers (Sorguçlar):**
# - Aykırı olmayan minimum ve maksimum değerleri gösteren çizgilerdir.
#
# **Simetriklik:**
# - Medyan ortadaysa ve sorguçlar eşitse dağılım simetriktir; değilse asimetridir.

# %%
df.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
plt.figure(figsize=(15,5)) #Grafiğini boyutunu belirler
sns.boxplot(x = "job_category", y = "salary_in_usd", data = df)
plt.xticks(rotation=90);

# %%
df.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
year_category_salary = df.groupby(["work_year","job_category"])[["salary_in_usd"]].mean().reset_index()
year_category_salary
# Out:
#     work_year                    job_category  salary_in_usd
# 0        2020                   Data Analysis   68014.666667
# 1        2020                Data Engineering   94575.823529
# 2        2020       Data Science and Research  129538.827586
# 3        2020         Machine Learning and AI  113276.400000
# 4        2021                   Data Analysis   87818.500000
# 5        2021  Data Architecture and Modeling  169940.600000
# 6        2021                Data Engineering  107192.288889
# 7        2021    Data Management and Strategy  165000.000000
# 8        2021       Data Science and Research  107517.819444
# 9        2021       Leadership and Management  131892.888889
# 10       2021         Machine Learning and AI  101396.891892
# 11       2022            BI and Visualization  100875.000000
# 12       2022              Cloud and Database  175000.000000
# 13       2022                   Data Analysis  107384.224913
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

plt.figure(figsize=(15,5)) #Grafiğini boyutunu belirler
sns.lineplot(x = "job_category", y = "salary_in_usd", hue = "work_year", data = year_category_salary)
plt.xticks(rotation=90);

# %%
import warnings
warnings.filterwarnings("ignore")

year_category_salary = df.groupby(["work_year","job_category"])[["salary_in_usd"]].mean().reset_index()
year_category_salary

year_category_salary["work_year"] = year_category_salary["work_year"].astype(str)

plt.figure(figsize=(15,5)) #Grafiğini boyutunu belirler
sns.barplot(x = "job_category", y = "salary_in_usd", hue = "work_year", data = year_category_salary, palette = "viridis")
plt.xlabel("İş kategorisi")
plt.ylabel("Ortalama maaş miktarı")
plt.title("Yıllara göre maaş miktar dağılımları")
plt.xticks(rotation=90);

# %%
import warnings
warnings.filterwarnings("ignore")

year_category_salary = df.groupby(["work_year","job_category"])[["salary_in_usd"]].mean().reset_index()
year_category_salary

year_category_salary["work_year"] = year_category_salary["work_year"].astype(str)

plt.figure(figsize=(15,5)) #Grafiğini boyutunu belirler
sns.barplot(x = "job_category", y = "salary_in_usd", hue = "work_year", data = year_category_salary, palette = "viridis")
plt.xlabel("İş kategorisi")
plt.ylabel("Ortalama maaş miktarı")
plt.title("Yıllara göre maaş miktar dağılımları")
plt.xticks(rotation=90);

# %% [markdown]
# - agg() metodunu, bir veri çerçevesinde veya serisinde çeşitli toplu fonksiyonlar uygulamak için kullanabilirsiniz. Bu fonksiyonlar, ortalama (mean), toplam (sum), medyan (median), minimum (min), maksimum (max) gibi işlemler olabilir.

# %%
df.groupby("job_category")[["salary_in_usd"]].agg(["mean","max","min"]).reset_index()
# Out:
#                      job_category  salary_in_usd
#                                             mean     max     min
# 0            BI and Visualization  135092.102236  259900   15000
# 1              Cloud and Database  155000.000000  190000  115000
# 2                   Data Analysis  108505.721345  430967   15000
# 3  Data Architecture and Modeling  156002.359073  376080   52500
# 4                Data Engineering  146197.656195  385000   18000
# 5    Data Management and Strategy  103139.934426  250000   46400
# 6     Data Quality and Operations  100879.472727  289120   23753
# 7       Data Science and Research  163758.575979  450000   16000
# 8       Leadership and Management  145476.019881  430640   20000
# 9         Machine Learning and AI  178925.847339  423000   15000

# %%
df.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
df["salary_currency"].unique()
# Out:
# array(['EUR', 'USD', 'GBP', 'CAD', 'AUD', 'PLN', 'BRL', 'TRY', 'CHF',
#        'SGD', 'DKK'], dtype=object)

# %%
df["salary_currency"].value_counts()
# Out:
# salary_currency
# USD    8591
# GBP     347
# EUR     340
# CAD      38
# AUD      11
# PLN       7
# SGD       6
# CHF       5
# BRL       4
# TRY       3
# DKK       3
# Name: count, dtype: int64

# %%
df[df["salary_currency"]=="TRY"]
# Out:
#       work_year       job_title               job_category salary_currency  \
# 4194       2023      BI Analyst       BI and Visualization             TRY
# 9247       2021  Data Scientist  Data Science and Research             TRY
# 9257       2021   Data Engineer           Data Engineering             TRY
#
#       salary  salary_in_usd employee_residence experience_level  \
# 4194  360000          18381             Turkey           Senior
# 9247  180000          20171             Turkey           Senior
# 9257  250000          28016             Turkey        Mid-level
#
#      employment_type work_setting company_location company_size
# 4194       Full-time       Remote           Turkey            L
# 9247       Full-time       Hybrid           Turkey            L
# 9257       Full-time       Remote           Turkey            M

# %%
df[(df["job_title"]=="Data Scientist") & (df["experience_level"]== "Senior") & (df["work_year"]== 2021)]
# Out:
#       work_year       job_title               job_category salary_currency  \
# 9187       2021  Data Scientist  Data Science and Research             EUR
# 9226       2021  Data Scientist  Data Science and Research             USD
# 9228       2021  Data Scientist  Data Science and Research             CAD
# 9247       2021  Data Scientist  Data Science and Research             TRY
# 9251       2021  Data Scientist  Data Science and Research             EUR
# 9266       2021  Data Scientist  Data Science and Research             USD
# 9319       2021  Data Scientist  Data Science and Research             CAD
#
#       salary  salary_in_usd employee_residence experience_level  \
# 9187   45000          53192             France           Senior
# 9226  165000         165000      United States           Senior
# 9228  130000         103691             Canada           Senior
# 9247  180000          20171             Turkey           Senior
# ...
